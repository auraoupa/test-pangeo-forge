# %%
import pandas as pd
import xarray as xr

# %%
from pangeo_forge_recipes.patterns import ConcatDim, FilePattern, pattern_from_file_sequence
from pangeo_forge_recipes.recipes import XarrayZarrRecipe,setup_logging

# %%
dates = pd.date_range('2009-07-01', '2009-07-10', freq='D')

# %%
URL_FORMAT = (
    "https://ige-meom-opendap.univ-grenoble-alpes.fr"
    "/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y{time:%Y}m{time:%m}d{time:%d}.1d_TSW_60m.nc"
)

# %%
input_urls= [ URL_FORMAT.format(time=time) for time in dates ]

# %%
pattern = pattern_from_file_sequence(input_urls, "time_counter")

# %%
pattern
# Out:
# <FilePattern {'time_counter': 10}>

# %%
recipe = XarrayZarrRecipe(pattern, target_chunks={"time_counter": 10,'x':2000,'y':2000})

# %%
setup_logging()

# %%
run_function = recipe.to_function()

# %%
run_function()
# Out:
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time_counter', index=0, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d01.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d01.1d_TSW_60m.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=0, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d01.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d01.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching metadata for input 'Index({DimIndex(name='time_counter', index=0, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time_counter', index=1, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d02.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d02.1d_TSW_60m.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=1, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d02.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d02.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching metadata for input 'Index({DimIndex(name='time_counter', index=1, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time_counter', index=2, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d03.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d03.1d_TSW_60m.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=2, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d03.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d03.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching metadata for input 'Index({DimIndex(name='time_counter', index=2, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time_counter', index=3, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d04.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d04.1d_TSW_60m.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=3, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d04.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d04.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching metadata for input 'Index({DimIndex(name='time_counter', index=3, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time_counter', index=4, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d05.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d05.1d_TSW_60m.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=4, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d05.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d05.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching metadata for input 'Index({DimIndex(name='time_counter', index=4, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time_counter', index=5, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d06.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d06.1d_TSW_60m.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=5, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d06.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d06.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching metadata for input 'Index({DimIndex(name='time_counter', index=5, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time_counter', index=6, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d07.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d07.1d_TSW_60m.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=6, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d07.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d07.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching metadata for input 'Index({DimIndex(name='time_counter', index=6, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time_counter', index=7, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d08.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d08.1d_TSW_60m.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=7, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d08.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d08.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching metadata for input 'Index({DimIndex(name='time_counter', index=7, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time_counter', index=8, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d09.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d09.1d_TSW_60m.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=8, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d09.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d09.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching metadata for input 'Index({DimIndex(name='time_counter', index=8, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time_counter', index=9, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d10.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d10.1d_TSW_60m.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=9, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d10.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d10.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching metadata for input 'Index({DimIndex(name='time_counter', index=9, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Creating a new dataset in target
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk Index({DimIndex(name='time_counter', index=0, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=0, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d01.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d01.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Combining inputs for chunk 'Index({DimIndex(name='time_counter', index=0, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# /srv/conda/envs/notebook/lib/python3.9/site-packages/pangeo_forge_recipes/recipes/xarray_zarr.py:115: RuntimeWarning: Failed to open Zarr store with consolidated metadata, falling back to try reading non-consolidated metadata. This is typically much slower for opening a dataset. To silence this warning, consider:
# 1. Consolidating metadata in this existing store with zarr.consolidate_metadata().
# 2. Explicitly setting consolidated=False, to avoid trying to read consolidate metadata, or
# 3. Explicitly setting consolidated=True, to raise an error in this case instead of falling back to try reading non-consolidated metadata.
#   return xr.open_zarr(target.get_mapper())
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing dataset in /tmp/tmp3s8s7jlc/13WPeSat
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Expanding target concat dim 'time_counter' to size 10
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk Index({DimIndex(name='time_counter', index=0, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=0, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d01.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d01.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Combining inputs for chunk 'Index({DimIndex(name='time_counter', index=0, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable time_counter chunk Index({DimIndex(name='time_counter', index=0, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(0, 1, None),)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable votemper chunk Index({DimIndex(name='time_counter', index=0, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(0, 1, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vosaline chunk Index({DimIndex(name='time_counter', index=0, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(0, 1, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vovecrtz chunk Index({DimIndex(name='time_counter', index=0, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(0, 1, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk Index({DimIndex(name='time_counter', index=1, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=1, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d02.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d02.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Combining inputs for chunk 'Index({DimIndex(name='time_counter', index=1, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable time_counter chunk Index({DimIndex(name='time_counter', index=1, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(1, 2, None),)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable votemper chunk Index({DimIndex(name='time_counter', index=1, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(1, 2, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vosaline chunk Index({DimIndex(name='time_counter', index=1, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(1, 2, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vovecrtz chunk Index({DimIndex(name='time_counter', index=1, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(1, 2, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk Index({DimIndex(name='time_counter', index=2, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=2, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d03.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d03.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Combining inputs for chunk 'Index({DimIndex(name='time_counter', index=2, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable time_counter chunk Index({DimIndex(name='time_counter', index=2, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(2, 3, None),)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable votemper chunk Index({DimIndex(name='time_counter', index=2, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(2, 3, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vosaline chunk Index({DimIndex(name='time_counter', index=2, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(2, 3, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vovecrtz chunk Index({DimIndex(name='time_counter', index=2, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(2, 3, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk Index({DimIndex(name='time_counter', index=3, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=3, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d04.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d04.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Combining inputs for chunk 'Index({DimIndex(name='time_counter', index=3, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable time_counter chunk Index({DimIndex(name='time_counter', index=3, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(3, 4, None),)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable votemper chunk Index({DimIndex(name='time_counter', index=3, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(3, 4, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vosaline chunk Index({DimIndex(name='time_counter', index=3, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(3, 4, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vovecrtz chunk Index({DimIndex(name='time_counter', index=3, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(3, 4, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk Index({DimIndex(name='time_counter', index=4, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=4, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d05.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d05.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Combining inputs for chunk 'Index({DimIndex(name='time_counter', index=4, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable time_counter chunk Index({DimIndex(name='time_counter', index=4, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(4, 5, None),)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable votemper chunk Index({DimIndex(name='time_counter', index=4, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(4, 5, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vosaline chunk Index({DimIndex(name='time_counter', index=4, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(4, 5, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vovecrtz chunk Index({DimIndex(name='time_counter', index=4, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(4, 5, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk Index({DimIndex(name='time_counter', index=5, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=5, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d06.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d06.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Combining inputs for chunk 'Index({DimIndex(name='time_counter', index=5, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable time_counter chunk Index({DimIndex(name='time_counter', index=5, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(5, 6, None),)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable votemper chunk Index({DimIndex(name='time_counter', index=5, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(5, 6, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vosaline chunk Index({DimIndex(name='time_counter', index=5, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(5, 6, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vovecrtz chunk Index({DimIndex(name='time_counter', index=5, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(5, 6, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk Index({DimIndex(name='time_counter', index=6, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=6, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d07.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d07.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Combining inputs for chunk 'Index({DimIndex(name='time_counter', index=6, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable time_counter chunk Index({DimIndex(name='time_counter', index=6, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(6, 7, None),)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable votemper chunk Index({DimIndex(name='time_counter', index=6, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(6, 7, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vosaline chunk Index({DimIndex(name='time_counter', index=6, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(6, 7, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vovecrtz chunk Index({DimIndex(name='time_counter', index=6, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(6, 7, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk Index({DimIndex(name='time_counter', index=7, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=7, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d08.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d08.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Combining inputs for chunk 'Index({DimIndex(name='time_counter', index=7, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable time_counter chunk Index({DimIndex(name='time_counter', index=7, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(7, 8, None),)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable votemper chunk Index({DimIndex(name='time_counter', index=7, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(7, 8, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vosaline chunk Index({DimIndex(name='time_counter', index=7, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(7, 8, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vovecrtz chunk Index({DimIndex(name='time_counter', index=7, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(7, 8, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk Index({DimIndex(name='time_counter', index=8, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=8, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d09.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d09.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Combining inputs for chunk 'Index({DimIndex(name='time_counter', index=8, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable time_counter chunk Index({DimIndex(name='time_counter', index=8, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(8, 9, None),)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable votemper chunk Index({DimIndex(name='time_counter', index=8, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(8, 9, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vosaline chunk Index({DimIndex(name='time_counter', index=8, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(8, 9, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vovecrtz chunk Index({DimIndex(name='time_counter', index=8, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(8, 9, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk Index({DimIndex(name='time_counter', index=9, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time_counter', index=9, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d10.1d_TSW_60m.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d10.1d_TSW_60m.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Combining inputs for chunk 'Index({DimIndex(name='time_counter', index=9, sequence_len=10, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable time_counter chunk Index({DimIndex(name='time_counter', index=9, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(9, 10, None),)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable votemper chunk Index({DimIndex(name='time_counter', index=9, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(9, 10, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vosaline chunk Index({DimIndex(name='time_counter', index=9, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(9, 10, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Storing variable vovecrtz chunk Index({DimIndex(name='time_counter', index=9, sequence_len=10, operation=<CombineOp.CONCAT: 2>)}) to Zarr region (slice(9, 10, None), slice(None, None, None), slice(None, None, None))
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Consolidating dimension coordinate arrays
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Consolidating Zarr metadata

# %%
mld_zarr = xr.open_zarr(recipe.target_mapper, consolidated=True)
mld_zarr
# Out:
# <xarray.Dataset>
# Dimensions:       (deptht: 1, y: 4729, x: 8354, time_counter: 10)
# Coordinates:
#   * deptht        (deptht) float32 61.27
#   * time_counter  (time_counter) datetime64[ns] 2009-07-01T12:00:00 ... 2009-...
# Dimensions without coordinates: y, x
# Data variables:
#     depthw        float64 ...
#     nav_lat       (y, x) float32 dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     nav_lon       (y, x) float32 dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     vosaline      (time_counter, y, x) float32 dask.array<chunksize=(10, 2000, 2000), meta=np.ndarray>
#     votemper      (time_counter, y, x) float32 dask.array<chunksize=(10, 2000, 2000), meta=np.ndarray>
#     vovecrtz      (time_counter, y, x) float32 dask.array<chunksize=(10, 2000, 2000), meta=np.ndarray>
# Attributes:
#     CASE:                       N/A
#     CONFIG:                     N/A
#     NCO:                        netCDF Operators version 4.7.4-alpha04 (http:...
#     history:                    Mon Sep 12 15:13:15 2022: ncap2 -O -s depthw=...
#     history_of_appended_files:  Mon Sep 12 15:13:15 2022: Appended file /mnt/...
#     nco_openmp_thread_number:   1
#     output_frequency:           N/A
#     start_date:                 -1

# %%
mld_zarr.votemper[0].plot()
