# %%
import xarray as xr

store = "https://ncsa.osn.xsede.org/Pangeo/pangeo-forge/test/pangeo-forge/staged-recipes/recipe-run-1164/eNATL60_wtides_1d_tsw60m.zarr"
ds = xr.open_dataset(store, engine='zarr', chunks={})
ds
# Out:
# <xarray.Dataset>
# Dimensions:       (deptht: 1, y: 4729, x: 8354, time_counter: 2)
# Coordinates:
#   * deptht        (deptht) float32 61.27
#   * time_counter  (time_counter) datetime64[ns] 2009-07-01T12:00:00 2009-07-0...
# Dimensions without coordinates: y, x
# Data variables:
#     depthw        float64 ...
#     nav_lat       (y, x) float32 dask.array<chunksize=(4729, 8354), meta=np.ndarray>
#     nav_lon       (y, x) float32 dask.array<chunksize=(4729, 8354), meta=np.ndarray>
#     vosaline      (time_counter, y, x) float32 dask.array<chunksize=(1, 4729, 8354), meta=np.ndarray>
#     votemper      (time_counter, y, x) float32 dask.array<chunksize=(1, 4729, 8354), meta=np.ndarray>
#     vovecrtz      (time_counter, y, x) float32 dask.array<chunksize=(1, 4729, 8354), meta=np.ndarray>
# Attributes:
#     CASE:                       N/A
#     CONFIG:                     N/A
#     NCO:                        netCDF Operators version 4.7.4-alpha04 (http:...
#     history:                    Mon Sep 12 15:13:15 2022: ncap2 -O -s depthw=...
#     history_of_appended_files:  Mon Sep 12 15:13:15 2022: Appended file /mnt/...
#     nco_openmp_thread_number:   1
#     output_frequency:           N/A
#     pangeo-forge:inputs_hash:   de15ba5766c51a35969aafe033ddef0f91f3e9cd1ce51...
#     pangeo-forge:recipe_hash:   ed684405d9c12c0c5685966beea54310056d73a31df66...
#     pangeo-forge:version:       0.9.1
#     start_date:                 -1

# %%
import xarray as xr

store = "https://ncsa.osn.xsede.org/Pangeo/pangeo-forge/test/pangeo-forge/staged-recipes/recipe-run-1163/eNATL60_wtides_1d_mld.zarr"
ds = xr.open_dataset(store, engine='zarr', chunks={})
ds
# Out:
# <xarray.Dataset>
# Dimensions:       (y: 4729, x: 8354, time_counter: 2)
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 2009-07-01T12:00:00 2009-07-0...
# Dimensions without coordinates: y, x
# Data variables:
#     nav_lat       (y, x) float32 dask.array<chunksize=(4729, 8354), meta=np.ndarray>
#     nav_lon       (y, x) float32 dask.array<chunksize=(4729, 8354), meta=np.ndarray>
#     somxl010      (time_counter, y, x) float32 dask.array<chunksize=(1, 4729, 8354), meta=np.ndarray>
# Attributes:
#     CASE:                      N/A
#     CONFIG:                    N/A
#     output_frequency:          N/A
#     pangeo-forge:inputs_hash:  606d08e0ec0fb020549fdf2d51c740d4f8109653ce2f22...
#     pangeo-forge:recipe_hash:  7d4e46d1fb55f6c87187ca1ef11ed8bc87048db7676cc6...
#     pangeo-forge:version:      0.9.1
#     start_date:                -1

# %%
import xarray as xr

store = "https://ncsa.osn.xsede.org/Pangeo/pangeo-forge/test/pangeo-forge/staged-recipes/recipe-run-1165/eNATL60_wtides_1d_tsw600m.zarr"
ds = xr.open_dataset(store, engine='zarr', chunks={})
ds
# Out:
# <xarray.Dataset>
# Dimensions:       (deptht: 1, y: 4729, x: 8354, time_counter: 2)
# Coordinates:
#   * deptht        (deptht) float32 599.7
#   * time_counter  (time_counter) datetime64[ns] 2009-07-01T12:00:00 2009-07-0...
# Dimensions without coordinates: y, x
# Data variables:
#     depthw        float64 ...
#     nav_lat       (y, x) float32 dask.array<chunksize=(4729, 8354), meta=np.ndarray>
#     nav_lon       (y, x) float32 dask.array<chunksize=(4729, 8354), meta=np.ndarray>
#     vosaline      (time_counter, y, x) float32 dask.array<chunksize=(1, 4729, 8354), meta=np.ndarray>
#     votemper      (time_counter, y, x) float32 dask.array<chunksize=(1, 4729, 8354), meta=np.ndarray>
#     vovecrtz      (time_counter, y, x) float32 dask.array<chunksize=(1, 4729, 8354), meta=np.ndarray>
# Attributes:
#     CASE:                       N/A
#     CONFIG:                     N/A
#     NCO:                        netCDF Operators version 4.7.4-alpha04 (http:...
#     history:                    Mon Sep 12 15:08:46 2022: ncap2 -O -s depthw=...
#     history_of_appended_files:  Mon Sep 12 15:04:06 2022: Appended file /mnt/...
#     nco_openmp_thread_number:   1
#     output_frequency:           N/A
#     pangeo-forge:inputs_hash:   3106b11354816c4149e8c9bb7f136f3b70d45563aca8c...
#     pangeo-forge:recipe_hash:   ab9d871ca08bd2aa2dc15d0a4c944190b6772066b37fc...
#     pangeo-forge:version:       0.9.1
#     start_date:                 -1
