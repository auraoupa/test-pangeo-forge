# %%
import pandas as pd
import xarray as xr

# %%
from pangeo_forge_recipes.patterns import ConcatDim, FilePattern
from pangeo_forge_recipes.recipes import XarrayZarrRecipe,setup_logging

# %%
dates = pd.date_range('2009-07-01', '2010-06-30', freq='D')

# %%
dates
# Out:
# DatetimeIndex(['2009-07-01', '2009-07-02', '2009-07-03', '2009-07-04',
#                '2009-07-05', '2009-07-06', '2009-07-07', '2009-07-08',
#                '2009-07-09', '2009-07-10',
#                ...
#                '2010-06-21', '2010-06-22', '2010-06-23', '2010-06-24',
#                '2010-06-25', '2010-06-26', '2010-06-27', '2010-06-28',
#                '2010-06-29', '2010-06-30'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
URL_FORMAT = (
    "https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/"
    "eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y{time:%Y}m{time:%m}d{time:%d}.1d_somxl010.nc"
)

# %%
def make_url(time):
    return URL_FORMAT.format(time=time)

# %%
truc=make_url(dates[0])

# %%
time_concat_dim = ConcatDim("time", dates, nitems_per_file=1)
time_concat_dim
# Out:
# ConcatDim(name='time', nitems_per_file=1)

# %%
pattern = FilePattern(make_url, time_concat_dim)
pattern
# Out:
# <FilePattern {'time': 365}>

# %%
for index, url in pattern.items():
    print(index)
    print(url)
    # Stop after the 3rd filepath (September 3rd, 1981)
    if 'y2009m07d05' in url:
        break
# Out:
# Index({DimIndex(name='time', index=0, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})
# https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d01.1d_somxl010.nc
# Index({DimIndex(name='time', index=1, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})
# https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d02.1d_somxl010.nc
# Index({DimIndex(name='time', index=2, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})
# https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d03.1d_somxl010.nc
# Index({DimIndex(name='time', index=3, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})
# https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d04.1d_somxl010.nc
# Index({DimIndex(name='time', index=4, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})
# https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d05.1d_somxl010.nc

# %%
target_chunks = {"time_counter": 1, "y": 1500}
recipe = XarrayZarrRecipe(pattern, target_chunks=target_chunks)
recipe
# Out:
# XarrayZarrRecipe(file_pattern=<FilePattern {'time': 365}>, storage_config=StorageConfig(target=FSSpecTarget(fs=<fsspec.implementations.local.LocalFileSystem object at 0x7f9fbc3c93f0>, root_path='/tmp/tmpresv6amq/mQR43nBN'), cache=CacheFSSpecTarget(fs=<fsspec.implementations.local.LocalFileSystem object at 0x7f9fbc3c93f0>, root_path='/tmp/tmpresv6amq/gO041kmh'), metadata=MetadataTarget(fs=<fsspec.implementations.local.LocalFileSystem object at 0x7f9fbc3c93f0>, root_path='/tmp/tmpresv6amq/W6by8Qhd')), inputs_per_chunk=1, target_chunks={'time_counter': 1, 'y': 1500}, cache_inputs=True, copy_input_to_local_file=False, consolidate_zarr=True, consolidate_dimension_coordinates=True, xarray_open_kwargs={}, xarray_concat_kwargs={}, delete_input_encoding=True, process_input=None, process_chunk=None, lock_timeout=None, subset_inputs={}, open_input_with_kerchunk=False)

# %%
setup_logging()

# %%
recipe.file_pattern
# Out:
# <FilePattern {'time': 365}>

# %%
run_function = recipe.to_function()

# %%
run_function()
# Out:
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=0, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d01.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d01.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=1, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d02.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d02.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=2, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d03.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d03.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=3, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d04.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d04.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=4, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d05.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d05.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=5, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d06.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d06.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=6, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d07.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d07.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=7, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d08.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d08.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=8, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d09.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d09.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=9, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d10.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d10.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=10, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d11.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d11.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=11, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d12.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d12.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=12, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d13.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d13.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=13, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d14.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d14.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=14, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d15.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d15.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=15, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d16.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d16.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=16, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d17.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d17.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=17, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d18.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d18.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=18, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d19.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d19.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=19, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d20.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d20.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=20, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d21.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d21.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=21, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d22.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d22.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=22, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d23.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d23.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=23, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d24.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d24.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=24, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d25.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d25.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=25, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d26.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d26.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=26, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d27.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d27.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=27, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d28.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d28.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=28, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d29.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d29.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=29, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d30.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d30.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=30, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d31.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d31.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=31, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d01.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d01.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=32, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d02.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d02.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=33, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d03.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d03.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=34, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d04.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d04.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=35, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d05.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d05.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=36, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d06.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d06.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=37, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d07.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d07.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=38, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d08.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d08.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=39, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d09.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d09.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=40, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d10.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d10.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=41, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d11.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d11.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=42, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d12.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d12.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=43, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d13.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d13.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=44, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d14.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d14.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=45, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d15.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d15.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=46, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d16.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d16.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=47, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d17.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d17.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=48, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d18.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d18.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=49, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d19.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d19.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=50, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d20.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d20.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=51, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d21.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d21.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=52, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d22.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d22.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=53, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d23.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d23.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=54, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d24.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d24.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=55, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d25.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d25.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=56, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d26.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d26.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=57, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d27.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d27.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=58, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d28.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d28.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=59, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d29.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d29.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=60, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d30.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d30.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=61, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d31.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m08d31.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=62, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d01.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d01.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=63, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d02.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d02.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=64, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d03.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d03.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=65, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d04.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d04.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=66, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d05.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d05.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=67, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d06.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d06.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=68, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d07.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d07.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=69, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d08.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d08.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=70, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d09.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d09.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=71, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d10.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d10.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=72, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d11.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d11.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=73, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d12.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d12.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=74, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d13.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d13.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=75, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d14.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d14.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=76, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d15.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d15.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=77, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d16.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d16.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=78, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d17.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d17.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=79, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d18.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d18.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=80, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.storage - INFO - Caching file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d19.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Copying remote file 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m09d19.1d_somxl010.nc' to cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Caching input 'Index({DimIndex(name='time', index=81, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# ...
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d23.1d_somxl010.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Combining inputs for chunk 'Index({DimIndex(name='time', index=22, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk Index({DimIndex(name='time', index=23, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time', index=23, sequence_len=365, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d24.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d24.1d_somxl010.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Combining inputs for chunk 'Index({DimIndex(name='time', index=23, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk Index({DimIndex(name='time', index=24, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time', index=24, sequence_len=365, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d25.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d25.1d_somxl010.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Combining inputs for chunk 'Index({DimIndex(name='time', index=24, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk Index({DimIndex(name='time', index=25, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time', index=25, sequence_len=365, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d26.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d26.1d_somxl010.nc' from cache
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Combining inputs for chunk 'Index({DimIndex(name='time', index=25, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})'
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk Index({DimIndex(name='time', index=26, sequence_len=365, operation=<CombineOp.CONCAT: 2>)})
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray Index({DimIndex(name='time', index=26, sequence_len=365, operation=<CombineOp.CONCAT: 2>)}): 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d27.1d_somxl010.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/eNATL60/eNATL60-BLBT02/1d/eNATL60-BLBT02_y2009m07d27.1d_somxl010.nc' from cache
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 run_function()
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/pangeo_forge_recipes/executors/python.py:44, in FunctionPipelineExecutor.compile.<locals>.function()
#      42 if stage.mappable is not None:
#      43     for m in stage.mappable:
# ---> 44         stage.function(m, config=pipeline.config)
#      45 else:
#      46     stage.function(config=pipeline.config)
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/pangeo_forge_recipes/recipes/xarray_zarr.py:585, in store_chunk(chunk_key, config)
#     582 if config.storage_config.target is None:
#     583     raise ValueError("target has not been set.")
# --> 585 with open_chunk(chunk_key, config=config) as ds_chunk:
#     586     # writing a region means that all the variables MUST have concat_dim
#     587     to_drop = [v for v in ds_chunk.variables if config.concat_dim not in ds_chunk[v].dims]
#     588     ds_chunk = ds_chunk.drop_vars(to_drop)
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/pangeo_forge_recipes/recipes/xarray_zarr.py:396, in open_chunk(chunk_key, config)
#     394 # need to open an unknown number of contexts at the same time
#     395 with ExitStack() as stack:
# --> 396     dsets = [stack.enter_context(open_input(input_key, config=config)) for input_key in inputs]
#     398     # subset before chunking; hopefully lazy
#     399     subset_dims = [dim_idx for dim_idx in chunk_key if dim_idx.operation == CombineOp.SUBSET]
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/pangeo_forge_recipes/recipes/xarray_zarr.py:396, in <listcomp>(.0)
#     394 # need to open an unknown number of contexts at the same time
#     395 with ExitStack() as stack:
# --> 396     dsets = [stack.enter_context(open_input(input_key, config=config)) for input_key in inputs]
#     398     # subset before chunking; hopefully lazy
#     399     subset_dims = [dim_idx for dim_idx in chunk_key if dim_idx.operation == CombineOp.SUBSET]
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/contextlib.py:492, in _BaseExitStack.enter_context(self, cm)
#     490 _cm_type = type(cm)
#     491 _exit = _cm_type.__exit__
# --> 492 result = _cm_type.__enter__(cm)
#     493 self._push_cm_exit(cm, _exit)
#     494 return result
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/pangeo_forge_recipes/recipes/xarray_zarr.py:338, in open_input(input_key, config)
#     336 logger.debug(f"about to enter xr.open_dataset context on {f}")
#     337 try:
# --> 338     with xr.open_dataset(f, **kw) as ds:
#     339         logger.debug("successfully opened dataset")
#     340         ds = fix_scalar_attr_encoding(ds)
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/backends/api.py:531, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, backend_kwargs, **kwargs)
#     519 decoders = _resolve_decoders_kwargs(
#     520     decode_cf,
#     521     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     527     decode_coords=decode_coords,
#     528 )
#     530 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 531 backend_ds = backend.open_dataset(
#     532     filename_or_obj,
#     533     drop_variables=drop_variables,
#     534     **decoders,
#     535     **kwargs,
#     536 )
#     537 ds = _dataset_from_backend_dataset(
#     538     backend_ds,
#     539     filename_or_obj,
#    (...)
#     547     **kwargs,
#     548 )
#     549 return ds
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/backends/h5netcdf_.py:401, in H5netcdfBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, format, group, lock, invalid_netcdf, phony_dims, decode_vlen_strings)
#     389 store = H5NetCDFStore.open(
#     390     filename_or_obj,
#     391     format=format,
#    (...)
#     396     decode_vlen_strings=decode_vlen_strings,
#     397 )
#     399 store_entrypoint = StoreBackendEntrypoint()
# --> 401 ds = store_entrypoint.open_dataset(
#     402     store,
#     403     mask_and_scale=mask_and_scale,
#     404     decode_times=decode_times,
#     405     concat_characters=concat_characters,
#     406     decode_coords=decode_coords,
#     407     drop_variables=drop_variables,
#     408     use_cftime=use_cftime,
#     409     decode_timedelta=decode_timedelta,
#     410 )
#     411 return ds
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/backends/store.py:41, in StoreBackendEntrypoint.open_dataset(self, store, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta)
#      27 encoding = store.get_encoding()
#      29 vars, attrs, coord_names = conventions.decode_cf_variables(
#      30     vars,
#      31     attrs,
#    (...)
#      38     decode_timedelta=decode_timedelta,
#      39 )
# ---> 41 ds = Dataset(vars, attrs=attrs)
#      42 ds = ds.set_coords(coord_names.intersection(vars))
#      43 ds.set_close(store.close)
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/core/dataset.py:599, in Dataset.__init__(self, data_vars, coords, attrs)
#     596 if isinstance(coords, Dataset):
#     597     coords = coords.variables
# --> 599 variables, coord_names, dims, indexes, _ = merge_data_and_coords(
#     600     data_vars, coords, compat="broadcast_equals"
#     601 )
#     603 self._attrs = dict(attrs) if attrs is not None else None
#     604 self._close = None
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/core/merge.py:575, in merge_data_and_coords(data_vars, coords, compat, join)
#     573 objects = [data_vars, coords]
#     574 explicit_coords = coords.keys()
# --> 575 return merge_core(
#     576     objects,
#     577     compat,
#     578     join,
#     579     explicit_coords=explicit_coords,
#     580     indexes=Indexes(indexes, coords),
#     581 )
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/core/merge.py:755, in merge_core(objects, compat, join, combine_attrs, priority_arg, explicit_coords, indexes, fill_value)
#     751 coerced = coerce_pandas_values(objects)
#     752 aligned = deep_align(
#     753     coerced, join=join, copy=False, indexes=indexes, fill_value=fill_value
#     754 )
# --> 755 collected = collect_variables_and_indexes(aligned, indexes=indexes)
#     756 prioritized = _get_priority_vars_and_indexes(aligned, priority_arg, compat=compat)
#     757 variables, out_indexes = merge_collected(
#     758     collected, prioritized, compat=compat, combine_attrs=combine_attrs
#     759 )
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/core/merge.py:365, in collect_variables_and_indexes(list_of_mappings, indexes)
#     362     indexes.pop(name, None)
#     363     append_all(coords, indexes)
# --> 365 variable = as_variable(variable, name=name)
#     366 if name in indexes:
#     367     append(name, variable, indexes[name])
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/core/variable.py:167, in as_variable(obj, name)
#     161     if obj.ndim != 1:
#     162         raise MissingDimensionsError(
#     163             f"{name!r} has more than 1-dimension and the same name as one of its "
#     164             f"dimensions {obj.dims!r}. xarray disallows such variables because they "
#     165             "conflict with the coordinates used to label dimensions."
#     166         )
# --> 167     obj = obj.to_index_variable()
#     169 return obj
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/core/variable.py:543, in Variable.to_index_variable(self)
#     541 def to_index_variable(self):
#     542     """Return this variable as an xarray.IndexVariable"""
# --> 543     return IndexVariable(
#     544         self.dims, self._data, self._attrs, encoding=self._encoding, fastpath=True
#     545     )
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/core/variable.py:2724, in IndexVariable.__init__(self, dims, data, attrs, encoding, fastpath)
#    2722 # Unlike in Variable, always eagerly load values into memory
#    2723 if not isinstance(self._data, PandasIndexingAdapter):
# -> 2724     self._data = PandasIndexingAdapter(self._data)
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/core/indexing.py:1418, in PandasIndexingAdapter.__init__(self, array, dtype)
#    1417 def __init__(self, array: pd.Index, dtype: DTypeLike = None):
# -> 1418     self.array = safe_cast_to_index(array)
#    1420     if dtype is None:
#    1421         self._dtype = get_valid_numpy_dtype(array)
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/core/utils.py:139, in safe_cast_to_index(array)
#     137     if hasattr(array, "dtype") and array.dtype.kind == "O":
#     138         kwargs["dtype"] = object
# --> 139     index = pd.Index(np.asarray(array), **kwargs)
#     140 return _maybe_cast_to_cftimeindex(index)
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/core/indexing.py:524, in LazilyIndexedArray.__array__(self, dtype)
#     522 def __array__(self, dtype=None):
#     523     array = as_indexable(self.array)
# --> 524     return np.asarray(array[self.key], dtype=None)
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/coding/variables.py:72, in _ElementwiseFunctionArray.__array__(self, dtype)
#      71 def __array__(self, dtype=None):
# ---> 72     return self.func(self.array)
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/coding/times.py:270, in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     268 if use_cftime is None:
#     269     try:
# --> 270         dates = _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     271     except (KeyError, OutOfBoundsDatetime, OutOfBoundsTimedelta, OverflowError):
#     272         dates = _decode_datetime_with_cftime(
#     273             flat_num_dates.astype(float), units, calendar
#     274         )
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/xarray/coding/times.py:223, in _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     221 with warnings.catch_warnings():
#     222     warnings.filterwarnings("ignore", "invalid value encountered", RuntimeWarning)
# --> 223     pd.to_timedelta(flat_num_dates.min(), delta) + ref_date
#     224     pd.to_timedelta(flat_num_dates.max(), delta) + ref_date
#     226 # To avoid integer overflow when converting to nanosecond units for integer
#     227 # dtypes smaller than np.int64 cast all integer and unsigned integer dtype
#     228 # arrays to np.int64 (GH 2002, GH 6589).  Note this is safe even in the case
#     229 # of np.uint64 values, because any np.uint64 value that would lead to
#     230 # overflow when converting to np.int64 would not be representable with a
#     231 # timedelta64 value, and therefore would raise an error in the lines above.
#
# File ~/miniconda3/envs/pangeo-forge/lib/python3.10/site-packages/numpy/core/_methods.py:44, in _amin(a, axis, out, keepdims, initial, where)
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
# ---> 44     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
mld_zarr_prune = xr.open_zarr(recipe.target_mapper, consolidated=True)
mld_zarr_prune
